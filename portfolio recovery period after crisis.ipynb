# %% [markdown]
# <a href="https://colab.research.google.com/github/mbk-dev/publications_RUS/blob/main/okid_usd_eur.ipynb"><img align="left" src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open in Colab" title="Open and Execute in Google Colaboratory"></a>

# %%
# !pip install okama

# %%
import matplotlib. pyplot as plt
import pandas as pd

import okama as ok
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ### Long Term Bonds Funds

# %%
bonds = ok.AssetList(['PINCX.US', 'NTHEX.US'])
bonds
# Out:
# symbols          [PINCX.US, NTHEX.US]
# currency                          USD
# first_date                    1980-02
# last_date                     2021-04
# period_length      41 years, 3 months
# inflation                    USD.INFL
# dtype: object

# %%
bonds.recovery_periods
# Out:
# PINCX.US    18
# NTHEX.US    80
# dtype: int32

# %% [markdown]
# ### Long Term Stocks

# %%
dji = ok.AssetList(['DJI.INDX'])

# %%
dji.drawdowns.plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
dji.recovery_periods / 12
# Out:
# DJI.INDX    16.166667
# dtype: float64

# %% [markdown]
# ### Assets US Portfolio

# %%
assets1 = ['PINCX.US', 'VFINX.US', 'FNER.INDX', 'GC.COMM']
assets2 = ['VBMFX.US', 'VFINX.US', 'FNER.INDX', 'GC.COMM']

# %%
labels = ['Облигации', 'Акции', 'Недвижимость', 'Золото']

# %% [markdown]
# ### Weights US portfolio (4 assets)

# %%
# Bonds, Stocks, REIT, Gold
wc = [0.55, 0.25, 0.15, 0.05]
sum(wc)
# Out:
# 1.0

# %%
fig1, ax1 = plt.subplots(figsize=(5, 5))
ax1.pie(wc, labels=labels, autopct='%1.0f%%', shadow=True, startangle=45, labeldistance=1.01, textprops={'fontsize': 14})
ax1.axis('equal');  # Equal aspect ratio ensures that pie is drawn as a circle.

# %%
# Bonds, Stocks, REIT, Gold
wb = [0.40, 0.40, 0.10, 0.10]
sum(wb)
# Out:
# 1.0

# %%
fig1, ax1 = plt.subplots(figsize=(5, 5))
ax1.pie(wb, labels=labels, autopct='%1.0f%%', shadow=True, startangle=90, labeldistance=1.1, textprops={'fontsize': 14})
ax1.axis('equal');  # Equal aspect ratio ensures that pie is drawn as a circle.

# %%
# Bonds, Stocks, REIT, Gold
wa = [0.10, 0.60, 0.10, 0.20]
sum(wa)
# Out:
# 1.0

# %%
fig1, ax1 = plt.subplots(figsize=(5, 5))
ax1.pie(wa, labels=labels, autopct='%1.0f%%', shadow=True, startangle=90, labeldistance=1.1, textprops={'fontsize': 14})
ax1.axis('equal');  # Equal aspect ratio ensures that pie is drawn as a circle.

# %% [markdown]
# ### Black Monday, 1987

# %%
fd = '1987-01'
ld = '1991-01'

# %%
al = ok.AssetList(assets1, first_date=fd, last_date=ld)
al
# Out:
# symbols          [PINCX.US, VFINX.US, FNER.INDX, GC.COMM]
# currency                                              USD
# first_date                                        1987-01
# last_date                                         1991-01
# period_length                           4 years, 1 months
# inflation                                        USD.INFL
# dtype: object

# %%
al.drawdowns.plot()
# Out:
# <AxesSubplot:>

# %%
pf_con = ok.Portfolio(assets1, weights=wc, first_date=fd, last_date=ld, symbol='Conservative.PF')
pf_bal = ok.Portfolio(assets1, weights=wb, symbol='Balanced.PF')
pf_agg = ok.Portfolio(assets1, weights=wa, symbol='Aggressive.PF')

# %%
pf_con.names
# Out:
# {'PINCX.US': 'PUTNAM INCOME FUND CLASS A SHARES',
#  'VFINX.US': 'VANGUARD 500 INDEX FUND INVESTOR SHARES',
#  'FNER.INDX': 'FTSE NAREIT All Equity REITs',
#  'GC.COMM': 'Gold'}

# %%
al_pf = ok.AssetList([pf_con, pf_bal, pf_agg])
al_pf
# Out:
# symbols          [Conservative.PF, Balanced.PF, Aggressive.PF]
# currency                                                   USD
# first_date                                             1987-01
# last_date                                              1991-01
# period_length                                4 years, 1 months
# inflation                                             USD.INFL
# dtype: object

# %%
al_pf.wealth_indexes.plot(logy=False)
# Out:
# <AxesSubplot:>

# %%
df = al_pf.wealth_indexes

# %%
fig = plt.figure(figsize=(12,6))
# fig.subplots_adjust(bottom=0.2, top=1.5)
ax = plt.gca()
ax.plot(df.index.to_timestamp(), df['Conservative.PF'], color = 'green', linewidth = 2, label='Консервативный портфель')
ax.plot(df.index.to_timestamp(), df['Balanced.PF'], color = 'blue', linewidth = 2, label='Сбалансированный портфель')
ax.plot(df.index.to_timestamp(), df['Aggressive.PF'], color = 'red', linewidth = 2, label='Агрессивный портфель')

ax.fill_between(df.index.to_timestamp(), 0, df['USD.INFL'], facecolor='grey', alpha=0.2, label='Инфляция')

ax.set_xlim('1987-01', '1991-01')
ax.set_ylim(980, 1410)

leg = ax.legend()

# %%
al.drawdowns.min()
# Out:
# PINCX.US    -0.066596
# VFINX.US    -0.297711
# FNER.INDX   -0.238771
# GC.COMM     -0.284661
# dtype: float64

# %%
al.recovery_periods / 12
# Out:
# PINCX.US     0.833333
# VFINX.US     1.666667
# FNER.INDX    1.500000
# GC.COMM      3.166667
# dtype: float64

# %%
al_pf.drawdowns.min()
# Out:
# Conservative.PF   -0.086844
# Balanced.PF       -0.124377
# Aggressive.PF     -0.181274
# dtype: float64

# %%
al_pf.recovery_periods / 12
# Out:
# Conservative.PF    0.750000
# Balanced.PF        1.333333
# Aggressive.PF      1.666667
# dtype: float64

# %% [markdown]
# ### Dotcom Bubble, 2000 - 2005

# %%
fd = '1999-01'
ld = '2007-01'

# %%
al = ok.AssetList(assets2, first_date=fd, last_date=ld)

# %%
al.drawdowns.plot()
# Out:
# <AxesSubplot:>

# %%
pf_con = ok.Portfolio(assets2, weights=wc, first_date=fd, last_date=ld, symbol='Conservative.PF')
pf_bal = ok.Portfolio(assets2, weights=wb, symbol='Balanced.PF')
pf_agg = ok.Portfolio(assets2, weights=wa, symbol='Aggressive.PF')

# %%
pf_con.names
# Out:
# {'VBMFX.US': 'VANGUARD TOTAL BOND MARKET INDEX FUND INVESTOR SHARES',
#  'VFINX.US': 'VANGUARD 500 INDEX FUND INVESTOR SHARES',
#  'FNER.INDX': 'FTSE NAREIT All Equity REITs',
#  'GC.COMM': 'Gold'}

# %%
al_pf = ok.AssetList([pf_con, pf_bal, pf_agg])
al_pf
# Out:
# symbols          [Conservative.PF, Balanced.PF, Aggressive.PF]
# currency                                                   USD
# first_date                                             1999-01
# last_date                                              2007-01
# period_length                                8 years, 1 months
# inflation                                             USD.INFL
# dtype: object

# %%
al_pf.wealth_indexes.plot(logy=False)
# Out:
# <AxesSubplot:>

# %%
df = al_pf.wealth_indexes

# %%
fig = plt.figure(figsize=(12,6))
# fig.subplots_adjust(bottom=0.2, top=1.5)
ax = plt.gca()
ax.plot(df.index.to_timestamp(), df['Conservative.PF'], color = 'green', linewidth = 2, label='Консервативный портфель')
ax.plot(df.index.to_timestamp(), df['Balanced.PF'], color = 'blue', linewidth = 2, label='Сбалансированный портфель')
ax.plot(df.index.to_timestamp(), df['Aggressive.PF'], color = 'red', linewidth = 2, label='Агрессивный портфель')

ax.fill_between(df.index.to_timestamp(), 0, df['USD.INFL'], facecolor='grey', alpha=0.2, label='Инфляция')

ax.set_xlim('2000-01', '2007-01')
ax.set_ylim(880, 1800)

leg = ax.legend()

# %%
al.drawdowns.min()
# Out:
# VBMFX.US    -0.034653
# VFINX.US    -0.448420
# FNER.INDX   -0.145800
# GC.COMM     -0.138281
# dtype: float64

# %%
al.recovery_periods / 12
# Out:
# VBMFX.US     1.000000
# VFINX.US     6.166667
# FNER.INDX    1.000000
# GC.COMM      2.333333
# dtype: float64

# %%
al_pf.drawdowns.min()
# Out:
# Conservative.PF   -0.050579
# Balanced.PF       -0.102596
# Aggressive.PF     -0.236155
# dtype: float64

# %%
al_pf.recovery_periods / 12
# Out:
# Conservative.PF    0.833333
# Balanced.PF        2.666667
# Aggressive.PF      3.250000
# dtype: float64

# %%
al_pf.describe()
# Out:
#                  property             period Aggressive.PF Balanced.PF  \
# 0         Compound return                YTD     -0.028610   -0.018680
# 1                    CAGR            1 years      0.070450    0.064585
# 2                    CAGR            5 years      0.035982    0.053620
# 3                    CAGR           10 years           NaN         NaN
# 4                    CAGR  7 years, 1 months      0.058445    0.062977
# 5                    Risk  7 years, 1 months      0.116225    0.078330
# 6                    CVAR  7 years, 1 months      0.131935    0.060389
# 7           Max drawdowns  7 years, 1 months     -0.236155   -0.102596
# 8     Max drawdowns dates  7 years, 1 months       2002-09     2002-09
# 9          Inception date               None       1987-12     1987-12
# 10        Last asset date               None       2021-04     2021-04
# 11  Common last data date               None       2005-01     2005-01
#
#    Conservative.PF inflation
# 0        -0.016690  0.002100
# 1         0.066656  0.029642
# 2         0.072623  0.024681
# 3              NaN       NaN
# 4         0.067369  0.023904
# 5         0.058419       NaN
# 6         0.014356       NaN
# 7        -0.054391       NaN
# 8          1998-08       NaN
# 9          1998-01   1998-01
# 10         2005-01   2005-01
# 11         2005-01   2005-01

# %% [markdown]
# ### US Housing Bubble. 2007-2009

# %%
fd = '2007-01'
ld = '2013-01'

# %%
al = ok.AssetList(assets2, first_date=fd, last_date=ld)

# %%
al.drawdowns.plot()
# Out:
# <AxesSubplot:>

# %%
pf_con = ok.Portfolio(assets2, weights=wc, first_date=fd, last_date=ld, symbol='Conservative.PF')
pf_bal = ok.Portfolio(assets2, weights=wb, symbol='Balanced.PF')
pf_agg = ok.Portfolio(assets2, weights=wa, symbol='Aggressive.PF')

# %%
al_pf = ok.AssetList([pf_con, pf_bal, pf_agg])
al_pf
# Out:
# symbols          [Conservative.PF, Balanced.PF, Aggressive.PF]
# currency                                                   USD
# first_date                                             2007-01
# last_date                                              2013-01
# period_length                                6 years, 1 months
# inflation                                             USD.INFL
# dtype: object

# %%
al_pf.wealth_indexes.plot(logy=False)
# Out:
# <AxesSubplot:>

# %%
df = al_pf.wealth_indexes

# %%
fig = plt.figure(figsize=(12,6))
# fig.subplots_adjust(bottom=0.2, top=1.5)
ax = plt.gca()
ax.plot(df.index.to_timestamp(), df['Conservative.PF'], color = 'green', linewidth = 2, label='Консервативный портфель')
ax.plot(df.index.to_timestamp(), df['Balanced.PF'], color = 'blue', linewidth = 2, label='Сбалансированный портфель')
ax.plot(df.index.to_timestamp(), df['Aggressive.PF'], color = 'red', linewidth = 2, label='Агрессивный портфель')

ax.fill_between(df.index.to_timestamp(), 0, df['USD.INFL'], facecolor='grey', alpha=0.2, label='Инфляция')

ax.set_xlim('2007-01', '2013-01')
ax.set_ylim(680, 1500)

leg = ax.legend()

# %%
al.drawdowns.min()
# Out:
# VBMFX.US    -0.039926
# VFINX.US    -0.509709
# FNER.INDX   -0.683038
# GC.COMM     -0.247843
# dtype: float64

# %%
al.recovery_periods / 12
# Out:
# VBMFX.US     0.666667
# VFINX.US     4.750000
# FNER.INDX    5.250000
# GC.COMM      1.416667
# dtype: float64

# %%
al_pf.drawdowns.min()
# Out:
# Conservative.PF   -0.233874
# Balanced.PF       -0.276105
# Aggressive.PF     -0.371073
# dtype: float64

# %%
al_pf.recovery_periods / 12
# Out:
# Conservative.PF    2.250000
# Balanced.PF        2.333333
# Aggressive.PF      2.916667
# dtype: float64

# %%
al_pf.describe()
# Out:
#                  property             period Aggressive.PF Balanced.PF  \
# 0         Compound return                YTD      0.034900    0.021940
# 1                    CAGR            1 years      0.107775    0.085078
# 2                    CAGR            5 years      0.069139    0.063307
# 3                    CAGR           10 years           NaN         NaN
# 4                    CAGR  6 years, 1 months      0.068008    0.061241
# 5                    Risk  6 years, 1 months      0.153480    0.110578
# 6                    CVAR  6 years, 1 months      0.334114    0.248222
# 7           Max drawdowns  6 years, 1 months     -0.371073   -0.276105
# 8     Max drawdowns dates  6 years, 1 months       2009-02     2009-02
# 9          Inception date               None       1987-12     1987-12
# 10        Last asset date               None       2021-04     2021-04
# 11  Common last data date               None       2013-01     2013-01
#
#    Conservative.PF inflation
# 0         0.014700  0.003000
# 1         0.073511  0.016036
# 2         0.062354  0.017558
# 3              NaN       NaN
# 4         0.058011  0.021917
# 5         0.097000       NaN
# 6         0.210105       NaN
# 7        -0.233874       NaN
# 8          2009-02       NaN
# 9          2007-01   2007-01
# 10         2013-01   2013-01
# 11         2013-01   2013-01

# %% [markdown]
# ### Russian Assets in 2008

# %%
fd = '2007-01'
ld = '2013-01'

# %% [markdown]
# ### Assets MIX Portfolio

# %%
assets_ru = ['RGBITR.INDX', 'VBMFX.US', 'MCFTR.INDX', 'VFINX.US', 'FNER.INDX', 'GC.COMM']

# %%
labels = ['Облигации RU', 'Облигации US', 'Акции RU', 'Акции US', 'Недвижимость', 'Золото']

# %% [markdown]
# ### Weights MIX RU-US Portfolio (6 assets), currency is RUB

# %%
# Bonds RU, Bonds US, Stocks RU, Stocks US, REIT, Gold
wc = [0.40, 0.15, 0.12, 0.13, 0.15, 0.05]
sum(wc)
# Out:
# 1.0

# %%
fig1, ax1 = plt.subplots(figsize=(5, 5))
ax1.pie(wc, labels=labels, autopct='%1.0f%%', shadow=True, startangle=80, labeldistance=1.01, textprops={'fontsize': 14})
ax1.axis('equal');  # Equal aspect ratio ensures that pie is drawn as a circle.

# %%
# Bonds RU, Bonds US, Stocks RU, Stocks US, REIT, Gold
wb = [0.20, 0.20, 0.20, 0.20, 0.10, 0.10]
sum(wb)
# Out:
# 1.0

# %%
fig1, ax1 = plt.subplots(figsize=(5, 5))
ax1.pie(wb, labels=labels, autopct='%1.0f%%', shadow=True, startangle=80, labeldistance=1.01, textprops={'fontsize': 14})
ax1.axis('equal');  # Equal aspect ratio ensures that pie is drawn as a circle.

# %%
# Bonds RU, Bonds US, Stocks RU, Stocks US, REIT, Gold
wa = [0.05, 0.05, 0.30, 0.30, 0.10, 0.20]
sum(wa)
# Out:
# 1.0

# %%
fig1, ax1 = plt.subplots(figsize=(5, 5))
ax1.pie(wa, labels=labels, autopct='%1.0f%%', shadow=True, startangle=80, labeldistance=1.01, textprops={'fontsize': 14})
ax1.axis('equal');  # Equal aspect ratio ensures that pie is drawn as a circle.

# %% [markdown]
# #### Asset List

# %%
al = ok.AssetList(assets_ru, first_date=fd, last_date=ld, ccy='RUB')
al
# Out:
# symbols          [RGBITR.INDX, VBMFX.US, MCFTR.INDX, VFINX.US, ...
# currency                                                       RUB
# first_date                                                 2007-01
# last_date                                                  2013-01
# period_length                                    6 years, 1 months
# inflation                                                 RUB.INFL
# dtype: object

# %%
al.drawdowns.plot()
# Out:
# <AxesSubplot:>

# %%
pf_con = ok.Portfolio(assets_ru, weights=wc, first_date=fd, last_date=ld, symbol='Conservative.PF', ccy='RUB')
pf_bal = ok.Portfolio(assets_ru, weights=wb, symbol='Balanced.PF', ccy='RUB')
pf_agg = ok.Portfolio(assets_ru, weights=wa, symbol='Aggressive.PF', ccy='RUB')

# %%
pf_con.table
# Out:
#                                           asset name       ticker  weights
# 0                      Russian Government Bond Index  RGBITR.INDX     0.40
# 1  VANGUARD TOTAL BOND MARKET INDEX FUND INVESTOR...     VBMFX.US     0.15
# 2                                  MOEX Total Return   MCFTR.INDX     0.12
# 3            VANGUARD 500 INDEX FUND INVESTOR SHARES     VFINX.US     0.13
# 4                       FTSE NAREIT All Equity REITs    FNER.INDX     0.15
# 5                                               Gold      GC.COMM     0.05

# %%
al_pf = ok.AssetList([pf_con, pf_bal, pf_agg])
al_pf
# Out:
# symbols          [Conservative.PF, Balanced.PF, Aggressive.PF]
# currency                                                   USD
# first_date                                             2007-01
# last_date                                              2013-01
# period_length                                6 years, 1 months
# inflation                                             USD.INFL
# dtype: object

# %%
al_pf.wealth_indexes.plot(logy=False)
# Out:
# <AxesSubplot:>

# %%
df = al_pf.wealth_indexes

# %%
fig = plt.figure(figsize=(12,6))
# fig.subplots_adjust(bottom=0.2, top=1.5)
ax = plt.gca()
ax.plot(df.index.to_timestamp(), df['Conservative.PF'], color = 'green', linewidth = 2, label='Консервативный портфель')
ax.plot(df.index.to_timestamp(), df['Balanced.PF'], color = 'blue', linewidth = 2, label='Сбалансированный портфель')
ax.plot(df.index.to_timestamp(), df['Aggressive.PF'], color = 'red', linewidth = 2, label='Агрессивный портфель')

ax.fill_between(df.index.to_timestamp(), 0, df['USD.INFL'], facecolor='grey', alpha=0.2, label='Инфляция')

ax.set_xlim('2007-01', '2013-01')
ax.set_ylim(680, 1500)

leg = ax.legend()

# %%
al.drawdowns.min()
# Out:
# RGBITR.INDX   -0.079350
# VBMFX.US      -0.125703
# MCFTR.INDX    -0.679146
# VFINX.US      -0.356165
# FNER.INDX     -0.577235
# GC.COMM       -0.172156
# dtype: float64

# %%
al.recovery_periods / 12
# Out:
# RGBITR.INDX    0.666667
# VBMFX.US       1.666667
# MCFTR.INDX     2.750000
# VFINX.US       3.416667
# FNER.INDX      4.583333
# GC.COMM        0.750000
# dtype: float64

# %%
al_pf.drawdowns.min()
# Out:
# Conservative.PF   -0.233874
# Balanced.PF       -0.276105
# Aggressive.PF     -0.371073
# dtype: float64

# %%
al_pf.recovery_periods / 12
# Out:
# Conservative.PF    1.750000
# Balanced.PF        1.833333
# Aggressive.PF      2.500000
# dtype: float64

# %%
al_pf.describe()
# Out:
#                  property             period Aggressive.PF Balanced.PF  \
# 0         Compound return                YTD      0.034900    0.021940
# 1                    CAGR            1 years      0.107775    0.085078
# 2                    CAGR            5 years      0.069139    0.063307
# 3                    CAGR           10 years           NaN         NaN
# 4                    CAGR  6 years, 1 months      0.068008    0.061241
# 5                    Risk  6 years, 1 months      0.153480    0.110578
# 6                    CVAR  6 years, 1 months      0.334114    0.248222
# 7           Max drawdowns  6 years, 1 months     -0.371073   -0.276105
# 8     Max drawdowns dates  6 years, 1 months       2009-02     2009-02
# 9          Inception date               None       1987-12     1987-12
# 10        Last asset date               None       2021-04     2021-04
# 11  Common last data date               None       2013-01     2013-01
#
#    Conservative.PF inflation
# 0         0.014700  0.003000
# 1         0.073511  0.016036
# 2         0.062354  0.017558
# 3              NaN       NaN
# 4         0.058011  0.021917
# 5         0.097000       NaN
# 6         0.210105       NaN
# 7        -0.233874       NaN
# 8          2009-02       NaN
# 9          2007-01   2007-01
# 10         2013-01   2013-01
# 11         2013-01   2013-01

# %% [markdown]
# ### 18 years (from 2003)

# %% [markdown]
# #### US

# %%
currency='USD'

# %%
fd = '2003-03'

# %%
al_us = ok.AssetList(assets2, first_date=fd, ccy='USD')
al_us
# Out:
# symbols          [VBMFX.US, VFINX.US, FNER.INDX, GC.COMM]
# currency                                              USD
# first_date                                        2003-03
# last_date                                         2021-04
# period_length                          18 years, 2 months
# inflation                                        USD.INFL
# dtype: object

# %%
al_us.wealth_indexes.plot(logy=True)
# Out:
# <AxesSubplot:>

# %%
pf_con_lt_us = ok.Portfolio(assets2, weights=wc, first_date=fd, symbol='Conservative.PF', ccy=currency)
pf_bal_lt_us = ok.Portfolio(assets2, weights=wb, symbol='Balanced.PF', ccy=currency)
pf_agg_lt_us = ok.Portfolio(assets2, weights=wa, symbol='Aggressive.PF', ccy=currency)

# %%
al_pf_lt_us = ok.AssetList([pf_con_lt_us, pf_bal_lt_us, pf_agg_lt_us], ccy=currency)
al_pf_lt_us
# Out:
# symbols          [Conservative.PF, Balanced.PF, Aggressive.PF]
# currency                                                   USD
# first_date                                             2003-03
# last_date                                              2021-04
# period_length                               18 years, 2 months
# inflation                                             USD.INFL
# dtype: object

# %%
al_pf_lt_us.wealth_indexes.plot(logy=True)
# Out:
# <AxesSubplot:>

# %%
al_pf_lt_us.get_rolling_cagr(window=12*10, real=True).plot()
# Out:
# <AxesSubplot:>

# %%
al_pf_lt_us.describe([5, 15, 18])
# Out:
#                  property              period Aggressive.PF Balanced.PF  \
# 0         Compound return                 YTD      0.068157    0.043016
# 1                    CAGR             5 years      0.131578    0.098581
# 2                    CAGR            15 years      0.092528    0.076431
# 3                    CAGR            18 years      0.104730    0.083614
# 4                    CAGR  18 years, 2 months      0.107049    0.085336
# 5                    Risk  18 years, 2 months      0.122419    0.087064
# 6                    CVAR  18 years, 2 months      0.306111    0.224761
# 7           Max drawdowns  18 years, 2 months     -0.371073   -0.276105
# 8     Max drawdowns dates  18 years, 2 months       2009-02     2009-02
# 9          Inception date                None       1987-12     1987-12
# 10        Last asset date                None       2021-04     2021-04
# 11  Common last data date                None       2021-04     2021-04
#
#    Conservative.PF inflation
# 0         0.033216  0.025333
# 1         0.078250  0.022238
# 2         0.067225  0.018970
# 3         0.073208  0.020977
# 4         0.074555  0.020995
# 5         0.075066       NaN
# 6         0.190963       NaN
# 7        -0.233874       NaN
# 8          2009-02       NaN
# 9          2003-03   2003-03
# 10         2021-04   2021-04
# 11         2021-04   2021-04

# %% [markdown]
# #### US + RUS

# %%
currency='USD'

# %%
al_mix = ok.AssetList(assets_ru, ccy=currency)
al_mix
# Out:
# symbols          [RGBITR.INDX, VBMFX.US, MCFTR.INDX, VFINX.US, ...
# currency                                                       USD
# first_date                                                 2003-03
# last_date                                                  2021-04
# period_length                                   18 years, 2 months
# inflation                                                 USD.INFL
# dtype: object

# %%
al_mix.wealth_indexes.plot(logy=True)
# Out:
# <AxesSubplot:>

# %%
pf_con_lt_mix = ok.Portfolio(assets_ru, weights=wc, symbol='Conservative.PF', ccy=currency)
pf_bal_lt_mix = ok.Portfolio(assets_ru, weights=wb, symbol='Balanced.PF', ccy=currency)
pf_agg_lt_mix = ok.Portfolio(assets_ru, weights=wa, symbol='Aggressive.PF', ccy=currency)

# %%
al_pf_lt_mix = ok.AssetList([pf_con_lt_mix, pf_bal_lt_mix, pf_agg_lt_mix], ccy=currency)
al_pf_lt_mix
# Out:
# symbols          [Conservative.PF, Balanced.PF, Aggressive.PF]
# currency                                                   USD
# first_date                                             2003-03
# last_date                                              2021-04
# period_length                               18 years, 2 months
# inflation                                             USD.INFL
# dtype: object

# %%
al_pf_lt_mix.wealth_indexes.plot(logy=True)
# Out:
# <AxesSubplot:>

# %%
pf_agg_lt_mix.wealth_index_with_assets.plot(logy=True)
# Out:
# <AxesSubplot:>

# %%
al_pf_lt_mix.get_rolling_cagr(window=12*10, real=True).plot()
# Out:
# <AxesSubplot:>

# %%
al_pf_lt_mix.describe([5, 15, 18])
# Out:
#                  property              period Aggressive.PF Balanced.PF  \
# 0         Compound return                 YTD      0.052719    0.030846
# 1                    CAGR             5 years      0.132899    0.106001
# 2                    CAGR            15 years      0.076554    0.064534
# 3                    CAGR            18 years      0.114386    0.092516
# 4                    CAGR  18 years, 2 months      0.117000    0.095067
# 5                    Risk  18 years, 2 months      0.174277    0.141654
# 6                    CVAR  18 years, 2 months      0.436740    0.365494
# 7           Max drawdowns  18 years, 2 months     -0.493084   -0.417664
# 8     Max drawdowns dates  18 years, 2 months       2009-02     2009-02
# 9          Inception date                None       2003-03     2003-03
# 10        Last asset date                None       2021-04     2021-04
# 11  Common last data date                None       2021-04     2021-04
#
#    Conservative.PF inflation
# 0         0.022555  0.025333
# 1         0.092931  0.022238
# 2         0.056265  0.018970
# 3         0.081226  0.020977
# 4         0.084127  0.020995
# 5         0.144738       NaN
# 6         0.358685       NaN
# 7        -0.406138       NaN
# 8          2009-02       NaN
# 9          2003-03   2003-03
# 10         2021-04   2021-04
# 11         2021-04   2021-04
