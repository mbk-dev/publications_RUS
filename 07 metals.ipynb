# %%
import okama as ok

# %%
com = ok.symbols_in_namespace('COMM')

# %%
com
# Out:
#      symbol ticker                         name country exchange currency  \
# 0   6A.COMM     6A    Australian Dollar Futures     USA     COMM      USD
# 1   6B.COMM     6B        British Pound Futures     USA     COMM      USD
# 2   6C.COMM     6C      Canadian Dollar Futures     USA     COMM      USD
# 3   6E.COMM     6E              Euro FX Futures     USA     COMM      USD
# 4   6J.COMM     6J         Japanese Yen Futures     USA     COMM      USD
# ..      ...    ...                          ...     ...      ...      ...
# 67  ZQ.COMM     ZQ  Thirty-Day Fed Fund Futures     USA     COMM      USD
# 68  ZR.COMM     ZR           Rough Rice Futures     USA     COMM      USD
# 69  ZS.COMM     ZS              Soybean Futures     USA     COMM      USD
# 70  ZT.COMM     ZT        2-Year T-Note Futures     USA     COMM      USD
# 71  ZW.COMM     ZW    Chicago SRW Wheat Futures     USA     COMM      USD
#
#             type
# 0   Common Stock
# 1   Common Stock
# 2   Common Stock
# ...

# %% [markdown]
# ### Драгоценные металлы

# %% [markdown]
# **Драгметаллы**
#
# - GC.COMM золото
# - SI.COMM серебро
# - PL.COMM платина
# - PA.COMM палладий
#
# **ETF драгметаллы**
#
# - XRH0.LSE родий
# - GLD.US золото
# - SLV.US серебра
#
# **Промышленные металлы**
#
# - MALTR.COMM алюминий
# - HG.COMM медь
# - SRR.COMM сталь

# %%
com[com['name'].str.contains("steel", case=False)]
# Out:
#       symbol ticker   name country exchange currency       type
# 51  SRR.COMM    SRR  Steel     USA     COMM      USD  Commodity

# %%
ok.search('XRH0')
# Out:
# [['XRH0.LSE', 'XRH0', 'db Physical Rhodium ETC', 'UK', 'LSE', 'USD', 'ETF']]

# %%
drag = ok.AssetList(['GC.COMM', 'SI.COMM', 'PL.COMM', 'PA.COMM'])
drag
# Out:
# symbols          [GC.COMM, SI.COMM, PL.COMM, PA.COMM]
# currency                                          USD
# first_date                                    2006-02
# last_date                                     2021-05
# period_length                      15 years, 3 months
# inflation                                    USD.INFL
# dtype: object

# %%
drag.assets_first_dates
# Out:
# {'USD': Timestamp('1913-02-01 00:00:00'),
#  'GC.COMM': Timestamp('1979-01-01 00:00:00'),
#  'SI.COMM': Timestamp('2000-02-01 00:00:00'),
#  'PL.COMM': Timestamp('2006-02-01 00:00:00'),
#  'PA.COMM': Timestamp('2006-02-01 00:00:00'),
#  'USD.INFL': Timestamp('1913-02-01 00:00:00')}

# %%
drag.wealth_indexes.plot()
# Out:
# <AxesSubplot:>

# %%
drag.wealth_indexes.plot()
# Out:
# <AxesSubplot:>
